# %%
import pandas as pd
import os
import csv
from sqlalchemy import create_engine

# %%
filepath = "/Users/Michael/Desktop/electiondata.xlsx"
filepath2 = "/Users/Michael/Desktop/coviddataGA.xlsx"

# %%
electiondf = pd.read_excel(filepath)
coviddf = pd.read_excel(filepath2)
electiondf.head()
# Out:
#   Unnamed: 0 Donald J. Trump (I) (Rep)              Unnamed: 2  \
# 0     County        Election Day Votes  Absentee by Mail Votes
# 1    Appling                      1753                     890
# 2   Atkinson                       716                     164
# 3      Bacon                       431                     487
# 4      Baker                       291                     138
#
#               Unnamed: 3         Unnamed: 4   Unnamed: 5  \
# 0  Advanced Voting Votes  Provisional Votes  Total Votes
# 1                   3874                  9         6526
# 2                   1419                  1         2300
# 3                   3099                  1         4018
# 4                    466                  2          897
#
#   Joseph R. Biden (Dem)              Unnamed: 7             Unnamed: 8  \
# 0    Election Day Votes  Absentee by Mail Votes  Advanced Voting Votes
# 1                   334                     587                    855
# ...

# %%
coviddf.head()
# Out:
#      County  Confirmed Cases  Confirmed Cases per 100k  \
# 0   Appling             1234                   6648.35
# 1  Atkinson              527                   6326.53
# 2     Bacon              663                   5813.75
# 3     Baker              107                   3433.89
# 4   Baldwin             2527                   5687.85
#
#    Antigen Positive Cases  Confirmed Deaths  Probable Deaths  Hospitalizations
# 0                     100                38                2               106
# 1                      72                 9                0                72
# 2                      87                20                4                52
# 3                      19                 6                0                21
# 4                     151                69                2               180

# %%
cleanelectiondf = electiondf[['Unnamed: 0', 'Unnamed: 5', 'Unnamed: 10', 'Unnamed: 15', 'Unnamed: 16']].copy()
cleanelectiondf.head()
# Out:
#   Unnamed: 0   Unnamed: 5  Unnamed: 10  Unnamed: 15 Unnamed: 16
# 0     County  Total Votes  Total Votes  Total Votes       Total
# 1    Appling         6526         1779           36        8341
# 2   Atkinson         2300          825           30        3155
# 3      Bacon         4018          625           25        4668
# 4      Baker          897          652            6        1555

# %%
cleanelectiondf.rename(columns={"Unnamed: 0": "County", "Unnamed: 5": "Donald J. Trump (Rep)",
                                "Unnamed: 10": "Joseph R. Biden (Dem)",
                                "Unnamed: 15": "Jo Jorgensen (Lib)",
                               "Unnamed: 16": "County Total"}, inplace=True)
cleanelectiondf.head()
# Out:
#      County Donald J. Trump (Rep) Joseph R. Biden (Dem) Jo Jorgensen (Lib)  \
# 0    County           Total Votes           Total Votes        Total Votes
# 1   Appling                  6526                  1779                 36
# 2  Atkinson                  2300                   825                 30
# 3     Bacon                  4018                   625                 25
# 4     Baker                   897                   652                  6
#
#   County Total
# 0        Total
# 1         8341
# 2         3155
# 3         4668
# 4         1555

# %%
df = cleanelectiondf.drop(cleanelectiondf.index[0])
finalelectiondf = df.reset_index(drop=True)
finalelectiondf
# Out:
#         County Donald J. Trump (Rep) Joseph R. Biden (Dem) Jo Jorgensen (Lib)  \
# 0      Appling                  6526                  1779                 36
# 1     Atkinson                  2300                   825                 30
# 2        Bacon                  4018                   625                 25
# 3        Baker                   897                   652                  6
# 4      Baldwin                  8903                  9140                208
# ..         ...                   ...                   ...                ...
# 155     Wilcox                  2403                   862                 16
# 156     Wilkes                  2823                  2160                 46
# 157  Wilkinson                  2664                  2075                 31
# 158      Worth                  6830                  2395                 60
# 159     Total:               2461837               2474507              62138
#
#     County Total
# ...

# %%
fulldata = pd.merge(finalelectiondf, coviddf, on='County', left_index=True)

# %%
fulldata
# Out:
#         County Donald J. Trump (Rep) Joseph R. Biden (Dem) Jo Jorgensen (Lib)  \
# 0      Appling                  6526                  1779                 36
# 1     Atkinson                  2300                   825                 30
# 2        Bacon                  4018                   625                 25
# 3        Baker                   897                   652                  6
# 4      Baldwin                  8903                  9140                208
# ..         ...                   ...                   ...                ...
# 156  Whitfield                 25636                 10670                440
# 157     Wilcox                  2403                   862                 16
# 158     Wilkes                  2823                  2160                 46
# 159  Wilkinson                  2664                  2075                 31
# 160      Worth                  6830                  2395                 60
#
# ...

# %%
fulldata.rename(columns={"County Total": "Total County Votes",
                        "Confirmed Cases": "Confirmed COVID-19 Cases"}, inplace=True)

# %%
fulldata
# Out:
#         County Donald J. Trump (Rep) Joseph R. Biden (Dem) Jo Jorgensen (Lib)  \
# 0      Appling                  6526                  1779                 36
# 1     Atkinson                  2300                   825                 30
# 2        Bacon                  4018                   625                 25
# 3        Baker                   897                   652                  6
# 4      Baldwin                  8903                  9140                208
# ..         ...                   ...                   ...                ...
# 156  Whitfield                 25636                 10670                440
# 157     Wilcox                  2403                   862                 16
# 158     Wilkes                  2823                  2160                 46
# 159  Wilkinson                  2664                  2075                 31
# 160      Worth                  6830                  2395                 60
#
# ...

# %%
#Upload to SQL server

connstring = "postgres:Michaelflyer1@localhost:5433/etlproject_db"
engine = create_engine(f'postgresql://{connstring}')

# %%
#Check table names

engine.table_names()
# Out:
# []
